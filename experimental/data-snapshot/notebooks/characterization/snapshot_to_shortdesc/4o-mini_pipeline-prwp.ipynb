# %%
import json
from pathlib import Path
import re
import time

from tqdm.auto import tqdm

from characterization import load_prompt, render_user_prompt, analyze_snapshot
from dsa.utils import load_json

# %% [markdown]
# # Inputs

# %%
# Inputs
SYSTEM_PROMPT_PATH = "system_message.md"
USER_PROMPT_PATH = "user_message.md"
MODEL_NAME = "gpt-4o-mini"
SLEEP_SECONDS = 0.2  # safety throttle

SNAPSHOTS_DIR = "../../../data/snapshots/prwp_batch2/"
METADATA_DIR = "/home/ajd/corpus/prwp/metadata/"
SOURCE_LABEL = "PRWP"
OUTPUT_PATH = f"data/results_{SOURCE_LABEL.lower()}_batch2.jsonl"

# %% [markdown]
# # Load data

# %%
system_prompt = load_prompt(SYSTEM_PROMPT_PATH)
user_prompt_template = load_prompt(USER_PROMPT_PATH)

# %%
metadata_files = list(Path(METADATA_DIR).glob("*.json"))
metadata_lookup = {x.stem: x for x in metadata_files}
len(metadata_files)
# Out:
# 10942

# %%
snapshot_files = list(Path(SNAPSHOTS_DIR).glob("*.png"))
len(snapshot_files)
# Out:
# 532

# %%
## Sampling
# import random
# snapshot_files = random.sample(snapshot_files, 100)
# len(snapshot_files)

# %% [markdown]
# # Main pipeline

# %%
# Build skip list
to_skip = set()
if Path(OUTPUT_PATH).exists():
    with open(OUTPUT_PATH, "r", encoding="utf-8") as f:
        for line in f:
            to_skip.add(json.loads(line)["snapshot_id"])

with open(OUTPUT_PATH, "a", encoding="utf-8") as out_f:
    for s in tqdm(snapshot_files):
        snapshot_id = s.name

        if snapshot_id in to_skip:
            print(f"Skipped: {s.name}")
            continue

        # Base row — every row has the same keys
        row = {
            "snapshot_id": snapshot_id,
            "image_path": str(s),
            "source_label": SOURCE_LABEL,
            "llm_output": None,
            "raw_output": None,
            "usage": None,
            "cost": None,
            "error": None,
        }

        try:
            # Infer metadata file from snapshot filename
            parts = re.split("(_figure|_table)", s.stem)
            fname = parts[0]
            label = parts[1].lstrip("_")
            metadata_path = metadata_lookup.get(fname)
            if metadata_path:
                metadata = load_json(metadata_path)

            # Build prompt variables
            v_title = (
                metadata["document_description"]["title_statement"]["title"]
                or "unknown"
            )
            v_date = (
                metadata.get("document_description").get("date_created")
                or metadata.get("document_description").get("date_available")
                or metadata.get("document_description").get("date_published")
                or "unknown"
            )
            v_language = "unknown"
            if metadata["document_description"]["languages"]:
                v_language = ", ".join(
                    [x["name"] for x in metadata["document_description"]["languages"]]
                )
            v_abstract = metadata["document_description"]["abstract"] or "unknown"
            prompt_vars = {
                "SOURCE_LABEL": SOURCE_LABEL,
                "DOCUMENT_TITLE": v_title,
                "YEAR": v_date,
                "LANGUAGE": v_language,
                "ABSTRACT": v_abstract,
                "SNAPSHOT_TYPE": label,
            }

            # Create user prompt
            user_prompt = render_user_prompt(user_prompt_template, prompt_vars)

            # Responses API
            result = analyze_snapshot(
                system_prompt=system_prompt,
                user_prompt=user_prompt,
                image_path=str(s),
                model=MODEL_NAME,
            )

            row["llm_output"] = result["parsed_output"]
            row["raw_output"] = result["raw_output"]
            row["usage"] = result["usage"].model_dump()
            row["cost"] = result["cost"]
            row["error"] = result["error"]  # None on success, message on parse failure

        except Exception as e:
            row["error"] = str(e)

        # Single write point — always executes
        out_f.write(json.dumps(row, ensure_ascii=False) + "\n")
        out_f.flush()

        time.sleep(SLEEP_SECONDS)
# Out:
#   0%|          | 0/532 [00:00<?, ?it/s]
# Skipped: document_13844807_table_002.png
# Skipped: document_7255556_table_003.png
# Skipped: document_13148967_table_015.png
# Skipped: document_15151160_figure_002.png
# Skipped: document_11777361_figure_007.png
# Skipped: document_717473_table_021.png
# Skipped: document_8772744_figure_008.png
# Skipped: document_14861148_figure_010.png
# Skipped: document_6596734_table_003.png
# Skipped: document_10000660_table_002.png
# Skipped: document_8772744_table_004.png
# Skipped: document_717449_table_001.png
# Skipped: document_10973627_table_000.png
# Skipped: document_8772744_figure_001.png
# Skipped: document_698797_table_001.png
# Skipped: document_10000660_figure_001.png
# Skipped: document_4991720_table_006.png
# Skipped: document_11174028_table_010.png
# Skipped: document_13840629_table_000.png
# Skipped: document_437268_table_000.png
# Skipped: document_10395051_table_000.png
# Skipped: document_443630_table_019.png
# Skipped: document_14861148_figure_013.png
# Skipped: document_13148967_figure_013.png
# Skipped: document_7063034_table_003.png
# Skipped: document_14491002_table_003.png
# Skipped: document_7255556_table_004.png
# Skipped: document_13840629_figure_003.png
# Skipped: document_10973627_figure_004.png
# Skipped: document_699634_table_003.png
# Skipped: document_11017288_figure_002.png
# Skipped: document_15151160_table_000.png
# Skipped: document_7063034_table_006.png
# Skipped: document_7367692_table_003.png
# Skipped: document_5800536_table_000.png
# Skipped: document_699634_table_004.png
# Skipped: document_7063025_table_006.png
# Skipped: document_699634_table_000.png
# Skipped: document_7367692_table_004.png
# Skipped: document_11332543_table_007.png
# Skipped: document_14860451_table_006.png
# Skipped: document_11017288_table_007.png
# Skipped: document_8772744_table_006.png
# Skipped: document_11332543_table_000.png
# Skipped: document_11174028_table_011.png
# Skipped: document_7581269_table_003.png
# Skipped: document_7581269_figure_004.png
# Skipped: document_7581269_table_004.png
# Skipped: document_7581269_table_008.png
# Skipped: document_13148967_table_006.png
# Skipped: document_11017288_table_002.png
# Skipped: document_14861148_figure_012.png
# Skipped: document_13148967_table_014.png
# Skipped: document_10973627_figure_007.png
# Skipped: document_11017288_table_014.png
# Skipped: document_717473_table_003.png
# Skipped: document_717473_table_019.png
# Skipped: document_17452144_figure_003.png
# Skipped: document_13148967_figure_000.png
# Skipped: document_13844807_table_001.png
# Skipped: document_10087951_table_006.png
# Skipped: document_7063025_table_008.png
# Skipped: document_11174028_table_016.png
# Skipped: document_7063025_table_000.png
# Skipped: document_717473_table_022.png
# Skipped: document_7581269_figure_003.png
# Skipped: document_11332543_table_004.png
# Skipped: document_443630_table_006.png
# Skipped: document_14861148_figure_016.png
# Skipped: document_10000660_table_006.png
# Skipped: document_7471923_table_006.png
# Skipped: document_443630_table_014.png
# Skipped: document_717473_table_017.png
# Skipped: document_5800536_table_002.png
# Skipped: document_14491002_table_006.png
# Skipped: document_11174028_table_002.png
# Skipped: document_14860451_table_005.png
# Skipped: document_717473_table_018.png
# Skipped: document_13148967_table_016.png
# Skipped: document_11332543_figure_001.png
# Skipped: document_695024_table_004.png
# Skipped: document_11777361_table_003.png
# Skipped: document_15348558_figure_002.png
# Skipped: document_717473_figure_000.png
# Skipped: document_437802_figure_001.png
# Skipped: document_11174028_table_007.png
# Skipped: document_7063034_table_002.png
# Skipped: document_4991720_table_003.png
# Skipped: document_695024_table_002.png
# Skipped: document_15348558_figure_007.png
# Skipped: document_13148967_table_003.png
# Skipped: document_11777361_figure_006.png
# Skipped: document_13148967_figure_009.png
# Skipped: document_6284707_figure_001.png
# Skipped: document_697372_table_005.png
# Skipped: document_11017288_table_006.png
# Skipped: document_11174028_figure_008.png
# Skipped: document_15348558_figure_000.png
# Skipped: document_7367692_table_000.png
# Skipped: document_4991720_table_008.png
# Skipped: document_697372_table_001.png
# Skipped: document_15348558_figure_004.png
# Skipped: document_7063025_figure_000.png
# Skipped: document_698797_table_002.png
# Skipped: document_4991720_table_001.png
# Skipped: document_10395051_table_002.png
# Skipped: document_13844807_figure_000.png
# Skipped: document_14861148_figure_002.png
# Skipped: document_10395051_table_001.png
# Skipped: document_11174028_table_008.png
# Skipped: document_11174028_figure_007.png
# Skipped: document_11017288_table_011.png
# Skipped: document_11332543_table_018.png
# Skipped: document_11174028_table_017.png
# Skipped: document_10395051_figure_005.png
# Skipped: document_10000660_figure_002.png
# Skipped: document_7581269_figure_002.png
# Skipped: document_698112_figure_002.png
# Skipped: document_11174028_table_003.png
# Skipped: document_437802_figure_007.png
# Skipped: document_7471923_table_000.png
# Skipped: document_13840629_figure_002.png
# Skipped: document_14491002_table_004.png
# Skipped: document_10087951_table_003.png
# Skipped: document_13148967_table_001.png
# Skipped: document_2176366_table_006.png
# Skipped: document_10395051_table_003.png
# Skipped: document_11017288_table_010.png
# Skipped: document_9058934_table_002.png
# Skipped: document_10395051_figure_006.png
# Skipped: document_15151160_table_001.png
# Skipped: document_11174028_table_006.png
# Skipped: document_15151160_table_002.png
# Skipped: document_11017288_table_012.png
# Skipped: document_11174028_figure_004.png
# Skipped: document_437802_figure_000.png
# Skipped: document_6284707_table_008.png
# Skipped: document_7063034_table_005.png
# Skipped: document_10973627_figure_000.png
# Skipped: document_13148967_table_017.png
# Skipped: document_11174028_figure_000.png
# Skipped: document_14861148_figure_017.png
# Skipped: document_7471923_table_004.png
# Skipped: document_7367692_table_002.png
# Skipped: document_14861148_figure_018.png
# Skipped: document_8772744_figure_004.png
# Skipped: document_10000660_table_005.png
# Skipped: document_7063025_table_004.png
# Skipped: document_717449_table_002.png
# Skipped: document_11017288_table_013.png
# Skipped: document_10000660_table_003.png
# Skipped: document_13148967_figure_005.png
# Skipped: document_443630_table_013.png
# Skipped: document_697372_table_002.png
# Skipped: document_7063025_table_009.png
# Skipped: document_7367692_table_006.png
# Skipped: document_717473_table_000.png
# Skipped: document_11777361_table_001.png
# Skipped: document_698112_figure_000.png
# Skipped: document_7063025_table_011.png
# Skipped: document_7581269_figure_000.png
# Skipped: document_11332543_table_005.png
# Skipped: document_7063034_table_001.png
# Skipped: document_17452144_figure_001.png
# Skipped: document_6284707_figure_002.png
# Skipped: document_6583121_figure_000.png
# Skipped: document_443630_table_000.png
# Skipped: document_13840629_figure_000.png
# Skipped: document_13148967_figure_012.png
# Skipped: document_7063034_table_007.png
# Skipped: document_7581269_table_002.png
# Skipped: document_11332543_table_012.png
# Skipped: document_11332543_table_002.png
# Skipped: document_11332543_figure_003.png
# Skipped: document_7255556_table_000.png
# Skipped: document_437802_figure_006.png
# Skipped: document_7367692_table_008.png
# Skipped: document_11777361_figure_008.png
# Skipped: document_13840629_figure_012.png
# Skipped: document_17452144_figure_000.png
# Skipped: document_7063025_table_001.png
# Skipped: document_11332543_table_003.png
# Skipped: document_10000660_table_008.png
# Skipped: document_13844807_table_010.png
# Skipped: document_10087951_table_001.png
# Skipped: document_8772744_table_008.png
# Skipped: document_1744000_table_001.png
# Skipped: document_6583121_figure_001.png
# Skipped: document_14860451_table_003.png
# Skipped: document_11017288_table_001.png
# Skipped: document_11777361_figure_009.png
# Skipped: document_11332543_figure_000.png
# Skipped: document_13844807_figure_002.png
# Skipped: document_17452144_figure_004.png
# Skipped: document_13148967_table_005.png
# Skipped: document_9058934_table_001.png
# Skipped: document_11332543_table_008.png
# Skipped: document_13844807_table_011.png
# Skipped: document_10395051_figure_007.png
# Skipped: document_717473_table_015.png
# Skipped: document_699863_table_001.png
# Skipped: document_11017288_table_015.png
# Skipped: document_10087951_table_004.png
# Skipped: document_13148967_table_013.png
# Skipped: document_14861148_figure_003.png
# Skipped: document_13148967_figure_008.png
# Skipped: document_4991720_table_009.png
# Skipped: document_437802_figure_002.png
# Skipped: document_11174028_table_012.png
# Skipped: document_717449_table_000.png
# Skipped: document_717473_table_016.png
# Skipped: document_7581269_table_005.png
# Skipped: document_11017288_table_005.png
# Skipped: document_4991720_table_011.png
# Skipped: document_443630_table_011.png
# Skipped: document_717473_table_002.png
# Skipped: document_7255556_table_001.png
# Skipped: document_7471923_table_008.png
# Skipped: document_4991720_table_004.png
# Skipped: document_14861148_table_002.png
# Skipped: document_11174028_table_020.png
# Skipped: document_14861148_figure_009.png
# Skipped: document_443630_table_005.png
# Skipped: document_695024_table_000.png
# Skipped: document_443630_table_015.png
# Skipped: document_437802_figure_004.png
# Skipped: document_443630_table_016.png
# Skipped: document_15348558_figure_008.png
# Skipped: document_443630_table_001.png
# Skipped: document_7581269_table_012.png
# Skipped: document_10973627_figure_001.png
# Skipped: document_8772744_figure_012.png
# Skipped: document_15151160_table_005.png
# Skipped: document_14861148_table_000.png
# Skipped: document_7367692_table_007.png
# Skipped: document_443630_table_025.png
# Skipped: document_13148967_figure_004.png
# Skipped: document_10395051_figure_002.png
# Skipped: document_8772744_figure_009.png
# Skipped: document_717473_table_007.png
# Skipped: document_7063034_figure_000.png
# Skipped: document_10973627_figure_002.png
# Skipped: document_17452144_figure_002.png
# Skipped: document_7581269_table_006.png
# Skipped: document_437802_table_001.png
# Skipped: document_7255556_table_002.png
# Skipped: document_698112_figure_001.png
# Skipped: document_14860451_table_004.png
# Skipped: document_14861148_figure_001.png
# Skipped: document_1744000_table_003.png
# Skipped: document_4991720_table_007.png
# Skipped: document_13148967_figure_001.png
# Skipped: document_15348558_table_001.png
# Skipped: document_11777361_table_002.png
# Skipped: document_437268_figure_001.png
# Skipped: document_443630_table_023.png
# Skipped: document_443630_table_017.png
# Skipped: document_11174028_table_004.png
# Skipped: document_13148967_figure_002.png
# Skipped: document_7367692_table_001.png
# Skipped: document_10973627_figure_008.png
# Skipped: document_7581269_table_001.png
# Skipped: document_13840629_figure_007.png
# Skipped: document_5800536_table_004.png
# Skipped: document_695024_figure_002.png
# Skipped: document_11174028_figure_003.png
# Skipped: document_11174028_table_000.png
# Skipped: document_14491002_table_000.png
# Skipped: document_7255556_table_005.png
# Skipped: document_13840629_figure_011.png
# Skipped: document_7063025_table_003.png
# Skipped: document_437268_table_002.png
# Skipped: document_10087951_table_000.png
# Skipped: document_437263_table_002.png
# Skipped: document_13148967_table_010.png
# Skipped: document_14861148_figure_006.png
# Skipped: document_437263_table_000.png
# Skipped: document_443630_table_018.png
# Skipped: document_7581269_figure_001.png
# Skipped: document_13844807_table_008.png
# Skipped: document_717473_table_011.png
# Skipped: document_6284707_table_006.png
# Skipped: document_8772744_table_003.png
# Skipped: document_437268_table_005.png
# Skipped: document_14860451_table_000.png
# Skipped: document_8772744_table_000.png
# Skipped: document_11174028_figure_005.png
# Skipped: document_11174028_figure_001.png
# Skipped: document_11777361_figure_003.png
# Skipped: document_695024_table_006.png
# Skipped: document_15151160_figure_003.png
# Skipped: document_443630_table_003.png
# Skipped: document_11777361_figure_000.png
# Skipped: document_699863_table_002.png
# Skipped: document_8772744_figure_000.png
# Skipped: document_10395051_table_005.png
# Skipped: document_13844807_figure_001.png
# Skipped: document_7581269_table_010.png
# Skipped: document_11332543_table_010.png
# Skipped: document_2176366_table_001.png
# Skipped: document_437268_figure_002.png
# Skipped: document_717473_table_009.png
# Skipped: document_11017288_table_000.png
# Skipped: document_11332543_table_011.png
# Skipped: document_717473_table_004.png
# Skipped: document_6284707_table_002.png
# Skipped: document_11017288_figure_001.png
# Skipped: document_10087951_figure_000.png
# Skipped: document_7063025_table_007.png
# Skipped: document_11017288_figure_003.png
# Skipped: document_699863_table_004.png
# Skipped: document_11017288_table_009.png
# Skipped: document_13148967_figure_011.png
# Skipped: document_11332543_table_006.png
# Skipped: document_7471923_table_007.png
# Skipped: document_437268_figure_000.png
# Skipped: document_10000660_table_007.png
# Skipped: document_6284707_table_004.png
# Skipped: document_10000660_table_001.png
# Skipped: document_11017288_figure_004.png
# Skipped: document_8772744_figure_002.png
# Skipped: document_13840629_figure_001.png
# Skipped: document_15151160_table_008.png
# Skipped: document_15151160_figure_000.png
# Skipped: document_14861148_figure_004.png
# Skipped: document_14491002_table_005.png
# Skipped: document_6284707_figure_003.png
# Skipped: document_8772744_figure_005.png
# Skipped: document_13844807_table_007.png
# Skipped: document_443630_table_002.png
# Skipped: document_13148967_figure_003.png
# Skipped: document_698797_figure_000.png
# Skipped: document_13844807_table_004.png
# Skipped: document_7581269_table_000.png
# Skipped: document_437802_figure_005.png
# Skipped: document_697372_table_000.png
# Skipped: document_10395051_table_004.png
# Skipped: document_699863_table_000.png
# Skipped: document_13148967_figure_010.png
# Skipped: document_443630_table_022.png
# Skipped: document_13148967_table_004.png
# Skipped: document_7581269_table_009.png
# Skipped: document_717473_table_006.png
# Skipped: document_717449_table_003.png
# Skipped: document_2176366_table_000.png
# Skipped: document_14861148_figure_014.png
# Skipped: document_15348558_table_000.png
# Skipped: document_443630_table_010.png
# Skipped: document_13148967_figure_006.png
# Skipped: document_11777361_figure_002.png
# Skipped: document_11174028_table_021.png
# Skipped: document_11332543_table_019.png
# Skipped: document_13840629_figure_010.png
# Skipped: document_17452144_figure_005.png
# Skipped: document_11332543_figure_002.png
# Skipped: document_8772744_figure_003.png
# Skipped: document_11174028_table_013.png
# Skipped: document_11017288_figure_000.png
# Skipped: document_5800536_table_001.png
# Skipped: document_437268_table_001.png
# Skipped: document_10000660_table_004.png
# Skipped: document_13840629_figure_005.png
# Skipped: document_9058934_table_000.png
# Skipped: document_6284707_table_000.png
# Skipped: document_717473_table_012.png
# Skipped: document_443630_table_009.png
# Skipped: document_11017288_table_003.png
# Skipped: document_13840629_figure_009.png
# Skipped: document_437268_table_004.png
# Skipped: document_11777361_table_004.png
# Skipped: document_695024_table_003.png
# Skipped: document_4991720_table_002.png
# Skipped: document_13844807_table_005.png
# Skipped: document_1744000_table_006.png
# Skipped: document_10395051_figure_004.png
# Skipped: document_11174028_table_005.png
# Skipped: document_13148967_table_002.png
# Skipped: document_717473_table_008.png
# Skipped: document_11017288_table_008.png
# Skipped: document_14861148_figure_005.png
# Skipped: document_699634_table_001.png
# Skipped: document_443630_table_020.png
# Skipped: document_11174028_table_014.png
# Skipped: document_11174028_table_018.png
# Skipped: document_4991720_table_000.png
# Skipped: document_7063034_table_000.png
# Skipped: document_437263_table_003.png
# Skipped: document_697372_table_004.png
# Skipped: document_8772744_table_007.png
# Skipped: document_10087951_table_005.png
# Skipped: document_11174028_table_009.png
# Skipped: document_697372_table_006.png
# Skipped: document_11174028_figure_006.png
# Skipped: document_13844807_table_003.png
# Skipped: document_15348558_figure_003.png
# Skipped: document_14861148_figure_008.png
# Skipped: document_10395051_figure_001.png
# Skipped: document_443630_table_021.png
# Skipped: document_699863_table_003.png
# Skipped: document_697372_table_003.png
# Skipped: document_15151160_table_009.png
# Skipped: document_14861148_figure_007.png
# Skipped: document_10973627_figure_005.png
# Skipped: document_5800536_table_003.png
# Skipped: document_13840629_figure_006.png
# Skipped: document_443630_table_012.png
# Skipped: document_13148967_figure_007.png
# Skipped: document_7063034_table_004.png
# Skipped: document_717473_table_010.png
# Skipped: document_15348558_figure_001.png
# Skipped: document_14491002_table_001.png
# Skipped: document_13148967_table_008.png
# Skipped: document_15151160_table_004.png
# Skipped: document_695024_figure_001.png
# Skipped: document_699634_table_002.png
# Skipped: document_6583121_table_000.png
# Skipped: document_11332543_figure_004.png
# Skipped: document_1744000_table_002.png
# Skipped: document_10000660_figure_000.png
# Skipped: document_717473_table_001.png
# Skipped: document_8772744_figure_010.png
# Skipped: document_1744000_table_004.png
# Skipped: document_7471923_table_002.png
# Skipped: document_698112_figure_003.png
# Skipped: document_8772744_table_001.png
# Skipped: document_6284707_table_007.png
# Skipped: document_7471923_table_005.png
# Skipped: document_9058934_figure_002.png
# Skipped: document_717473_figure_001.png
# Skipped: document_443630_table_007.png
# Skipped: document_8772744_figure_007.png
# Skipped: document_13840629_figure_008.png
# Skipped: document_13148967_table_007.png
# Skipped: document_13844807_table_000.png
# Skipped: document_4991720_table_005.png
# Skipped: document_14860451_table_002.png
# Skipped: document_11777361_figure_005.png
# Skipped: document_10973627_table_001.png
# Skipped: document_10973627_figure_003.png
# Skipped: document_10973627_figure_006.png
# Skipped: document_11017288_table_004.png
# Skipped: document_7471923_table_009.png
# Skipped: document_437802_figure_008.png
# Skipped: document_7063034_table_008.png
# Skipped: document_2176366_table_004.png
# Skipped: document_6596734_table_000.png
# Skipped: document_7581269_table_011.png
# Skipped: document_15348558_figure_006.png
# Skipped: document_437802_table_000.png
# Skipped: document_11332543_table_016.png
# Skipped: document_14861148_figure_011.png
# Skipped: document_11332543_table_017.png
# Skipped: document_10395051_figure_008.png
# Skipped: document_2176366_table_005.png
# Skipped: document_11777361_figure_010.png
# Skipped: document_6284707_figure_000.png
# Skipped: document_11332543_table_014.png
# Skipped: document_10973627_table_002.png
# Skipped: document_15348558_table_002.png
# Skipped: document_8772744_figure_006.png
# Skipped: document_11777361_figure_001.png
# Skipped: document_13148967_table_009.png
# Skipped: document_14861148_figure_015.png
# Skipped: document_695024_table_005.png
# Skipped: document_443630_table_004.png
# Skipped: document_6284707_table_003.png
# Skipped: document_2176366_table_003.png
# Skipped: document_14861148_table_001.png
# Skipped: document_11017288_table_017.png
# Skipped: document_7063025_table_005.png
# Skipped: document_10395051_figure_000.png
# Skipped: document_15151160_table_003.png
# Skipped: document_15151160_table_006.png
# Skipped: document_14491002_table_002.png
# Skipped: document_7471923_table_001.png
# Skipped: document_7581269_table_007.png
# Skipped: document_1744000_table_005.png
# Skipped: document_695024_figure_000.png
# Skipped: document_6596734_table_001.png
# Skipped: document_6284707_table_005.png
# Skipped: document_8772744_table_005.png
# Skipped: document_443630_table_008.png
# Skipped: document_13840629_figure_004.png
# Skipped: document_11332543_table_013.png
# Skipped: document_6596734_table_002.png
# Skipped: document_11174028_table_001.png
# Skipped: document_7063025_table_002.png
# Skipped: document_6284707_table_001.png
# Skipped: document_11332543_table_009.png
# Skipped: document_7063025_table_010.png
# Skipped: document_695024_table_001.png
# Skipped: document_10000660_table_000.png
# Skipped: document_11332543_table_015.png
# Skipped: document_15151160_table_007.png
# Skipped: document_717473_table_005.png
# Skipped: document_9058934_figure_000.png
# Skipped: document_13148967_table_000.png
# Skipped: document_7367692_table_005.png
# Skipped: document_8772744_figure_011.png
# Skipped: document_9058934_figure_001.png
# Skipped: document_11017288_table_016.png
# Skipped: document_4991720_table_010.png
# Skipped: document_15151160_figure_004.png
# Skipped: document_11174028_table_019.png
# Skipped: document_437263_table_001.png
# Skipped: document_13148967_table_012.png
# Skipped: document_2176366_table_002.png
# Skipped: document_13844807_table_009.png
# Skipped: document_14861148_figure_000.png
# Skipped: document_11332543_table_001.png
# Skipped: document_437268_table_003.png
# Skipped: document_717473_table_014.png
# Skipped: document_1744000_table_000.png
# Skipped: document_10087951_table_002.png
# Skipped: document_13148967_table_011.png
# Skipped: document_11777361_table_000.png
# Skipped: document_10395051_figure_003.png
# Skipped: document_443630_table_024.png
# Skipped: document_13844807_table_006.png
# Skipped: document_437802_figure_003.png
# Skipped: document_717473_table_020.png
# Skipped: document_14860451_table_001.png
# Skipped: document_11777361_figure_004.png
# Skipped: document_11174028_figure_002.png
# Skipped: document_8772744_table_002.png
# Skipped: document_11174028_table_015.png
# Skipped: document_15151160_figure_001.png
# Skipped: document_717473_table_013.png
# Skipped: document_15348558_figure_005.png
# Skipped: document_12714605_table_000.png
# Skipped: document_698797_table_000.png
