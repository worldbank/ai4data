# %%
from openpyxl import load_workbook
from tqdm.auto import tqdm

# %%
wb = load_workbook("../../corpus/refugee/Results Data_project_docs_refugee.xlsx", data_only=True)
ws = wb['data']
url_list = [
    cell.hyperlink.target
    for row in ws.iter_rows(min_row=2)
    if (cell := row[0]).hyperlink
]
guid_list = [x.split("/")[-1] for x in url_list]
len(guid_list)
# Out:
# 203

# %%
# %cd "../../ai4data/"

for x in tqdm(guid_list):
    # !uv run python scripts/metadata/wds_to_schema.py --guid=$x --output_dir=metadata --no-deduplicate
# Out:
# /home/ajd/ai4data
# /home/ajd/miniconda3/envs/data-snapshot/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#   0%|          | 0/203 [00:00<?, ?it/s]
# Saved metadata/document_40062872.json
# Saved metadata/document_40013709.json
# Saved metadata/document_40010124.json
# Saved metadata/document_34459919.json
# Saved metadata/document_34423532.json
# Saved metadata/document_34389109.json
# Saved metadata/document_34297879.json
# Saved metadata/document_34288986.json
# Saved metadata/document_34277348.json
# Saved metadata/document_34266217.json
# Saved metadata/document_34213041.json
# Saved metadata/document_34207938.json
# Saved metadata/document_34201758.json
# Saved metadata/document_34194872.json
# Saved metadata/document_34073066.json
# Saved metadata/document_34068431.json
# ...
