# %% [markdown]
# ## Example script to run the Metadata Reviewer with non-default agents manifest

# %%
import os
import re
import csv
import math
import asyncio
import requests
import pandas as pd
from tqdm import tqdm
from dotenv import load_dotenv
from ai4data.metadata.reviewer import MetadataReviewerClient

# %%
ASSETS_DIR = None # If None, uses the predefined manifest directory within the package

# Available predefined manifest files
DEFAULT_MANIFEST = "default_agents_manifest.yml"
SINGLE_PASS_MANIFEST = "single_pass_agent_manifest.yml"
TYPO_MANIFEST = "typo_agent_manifest.yml"

# %%
# Load OPENAI_API_KEY from the .env file
load_dotenv(".env")
openai_api_key = os.environ["OPENAI_API_KEY"]

# Initialize the client using OpenAI
client = MetadataReviewerClient.from_openai(model="gpt-5.4-2026-03-05", api_key=openai_api_key, assets_dir=ASSETS_DIR)
# client = MetadataReviewerClient.from_ollama(model="gemma4:31b", host="http://w1lxscirender01.worldbank.org", port=8080, assets_dir=ASSETS_DIR)

# %%
# Load ME_API_KEY from the .env file in the current working directory
load_dotenv()
ME_API_KEY = os.getenv("ME_API_KEY")
ME_URL = 'https://metadataeditor.worldbank.org/index.php'
ME_HEADERS = {"X-API-KEY": ME_API_KEY}

# define functions for Metadata Editor operations
def fetch_me_collection_list():
    """
    Fetch collection list from the Metadata Editor.
    """
    response = requests.get(f"{ME_URL}/api/collections", headers=ME_HEADERS)
    response.raise_for_status()
    collection_list = [f"[{collection['id']}] {collection['title']}" for collection in response.json()['collections']]
    collection_list = sorted(collection_list, key=lambda s: int(re.search(r"\[(\d+)\]", s).group(1)) if re.search(r"\[(\d+)\]", s) else float("inf"))
    return collection_list

def fetch_me_project_list(collection):
    """
    Fetch project list from the Metadata Editor.
    """
    collection_id = re.search(r"\[(\d+)\]", collection).group(1)
    search_params = []
    search_params.append(f"collection={collection_id}")   
    probe_params = search_params.copy()
    probe_params.append(f"offset=0&limit=1")
    response = requests.get(f"{ME_URL}/api/editor/?{'&'.join(probe_params)}", headers=ME_HEADERS)
    total_cases = response.json().get("total", 0)
    limit = 500
    project_list = []
    num_pages = math.ceil(total_cases / limit) if limit else 0
    for offset in tqdm(range(0, total_cases, limit), total=num_pages):
        search_more_params = search_params.copy()
        search_more_params.append(f"offset={offset}&limit={limit}")
        response = requests.get(f"{ME_URL}/api/editor/?{'&'.join(search_more_params)}", headers=ME_HEADERS)
        if response.status_code != 200:
            raise Exception(f"Something wrong with the Metadata Editor search: {response.text}")
        data = response.json()
        project_list.extend(data.get("projects", []))

    project_title_list = [f"[{project['id']}] {project['title']}" for project in project_list]
    project_title_list = sorted(project_title_list, key=lambda s: int(re.search(r"\[(\d+)\]", s).group(1)) if re.search(r"\[(\d+)\]", s) else float("inf"))
    default_value = project_title_list[0] if project_title_list else None
    return project_title_list

def fetch_me_project_metadata(project):
    """
    Fetch project metadata from the Metadata Editor.
    """
    project_id = re.search(r"\[(\d+)\]", project).group(1)
    response = requests.get(f"{ME_URL}/api/editor/{project_id}", headers=ME_HEADERS)
    if response.status_code != 200:
        raise Exception(f"Something wrong with the Metadata Editor search: {response.text}")
    metadata = response.json()['project']['metadata']
    metadata.get("series_description", {}).pop("ref_country", None)
    metadata.get("series_description", {}).pop("geographic_units", None)
    return metadata

def filter_keys(obj, allowed, path=""):
    if isinstance(obj, dict):
        return {
            k: v if (p := f"{path}.{k}" if path else k) in allowed
            else filter_keys(v, allowed, p)
            for k, v in obj.items()
            if (p := f"{path}.{k}" if path else k) in allowed
            or any(a.startswith(p + ".") for a in allowed)
        }
    if isinstance(obj, list):
        return [filter_keys(i, allowed, path) for i in obj]
    return obj

# %%
async def process_one(me_collection, me_project, semaphore):
    async with semaphore:    
        # fetch metadata
        metadata_to_scan = fetch_me_project_metadata(me_project)
        metadata_to_scan = filter_keys(
            metadata_to_scan,
            {
                "series_description.name",
                "series_description.measurement_unit",
                "series_description.dimensions",
                "series_description.definition_long",
                "series_description.methodology",
                "series_description.topics",
                "series_description.relevance",
                "series_description.statistical_concept",
            }
        )

        # Build URL from [12345] pattern in me_project
        m = re.search(r"\[(\d+)\]", str(me_project))
        if not m:
            raise ValueError("Could not extract project_id from ME_project (expected [12345] pattern).")
        project_id = m.group(1)
        me_url = f"{ME_URL}/api/editor/{project_id}"

        # start agents activity
        job = await client.submit_async(metadata_to_scan, manifest_file=SINGLE_PASS_MANIFEST)

        try:
            result = await job.wait()

            return {
                "ME_collection": me_collection,
                "ME_project": me_project,
                "ME_url": me_url,
                "detected_issues": result,
            }

        except Exception as e:
            print(f"[Warning] Failed for project: {me_project}. Reason: {e}")
            return {
                "ME_collection": me_collection,
                "ME_project": me_project,
                "ME_url": me_url,
                "detected_issues": "",
            }

# %%
MAX_CONCURRENT_JOBS = 10
async def run_parallel(metadata_items, output_file_name):
    semaphore = asyncio.Semaphore(MAX_CONCURRENT_JOBS)
    fieldnames = ['ME_collection', 'ME_project', 'ME_url', 'detected_issues']

    file_exists = os.path.exists(output_file_name)
    if file_exists:
        output_df = pd.read_csv(output_file_name)
    else:
        output_df = pd.DataFrame(columns=fieldnames)

    with open(output_file_name, "a", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
            f.flush()

        # skip projects that are already completed
        done = set(output_df["ME_project"].astype(str))
        todo = [(collection, project) for (collection, project) in metadata_items if str(project) not in done]        
        tasks = [
            asyncio.create_task(process_one(collection, project, semaphore))
            for collection, project in todo
        ]
        
        done_count = 0
        for future in asyncio.as_completed(tasks):
            row = await future
            writer.writerow(row)
            f.flush()
            done_count += 1
            print(f"[{done_count}/{len(todo)}] done: {row['ME_project']}")

# %%
me_collection = "[18] WDI - National Accounts"
me_project_list = fetch_me_project_list(me_collection)
metadata_items = [(me_collection, me_project) for me_project in me_project_list]
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.10s/it]

# %%
output_file_name = "WDI_National_Accounts_detected_metadata_issues_20260421.csv"
await run_parallel(metadata_items, output_file_name)
# Out:
# [1/171] done: [623] General government final consumption expenditure (% of GDP)
# [2/171] done: [622] General government final consumption expenditure (constant LCU)
# [3/171] done: [620] General government final consumption expenditure (constant 2015 US$)
# [4/171] done: [619] General government final consumption expenditure (current LCU)
# [5/171] done: [624] Households and NPISHs final consumption expenditure (current US$)
# [6/171] done: [625] Households and NPISHs final consumption expenditure (current LCU)
# [7/171] done: [627] Households and NPISHs final consumption expenditure (constant 2015 US$)
# [8/171] done: [621] General government final consumption expenditure (annual % growth)
# [9/171] done: [626] Households and NPISHs final consumption expenditure, linked series (current LCU)
# [10/171] done: [618] General government final consumption expenditure (current US$)
# [11/171] done: [630] Households and NPISHs final consumption expenditure per capita (constant 2015 US$)
# [12/171] done: [628] Households and NPISHs final consumption expenditure (annual % growth)
# [13/171] done: [631] Households final consumption expenditure per capita (annual % growth)
# [14/171] done: [629] Households and NPISHs final consumption expenditure (constant LCU)
# [15/171] done: [635] Final consumption expenditure (current US$)
# [16/171] done: [641] Gross national expenditure deflator (base year varies by country)
# [17/171] done: [636] Final consumption expenditure (current LCU)
# [18/171] done: [634] Households and NPISHs final consumption expenditure (% of GDP)
# [19/171] done: [637] Final consumption expenditure (constant 2015 US$)
# [20/171] done: [638] Final consumption expenditure (annual % growth)
# [21/171] done: [639] Final consumption expenditure (constant LCU)
# [22/171] done: [640] Final consumption expenditure (% of GDP)
# [23/171] done: [642] Gross national expenditure (current US$)
# [24/171] done: [643] Gross national expenditure (current LCU)
# [25/171] done: [644] Gross national expenditure (constant 2015 US$)
# [26/171] done: [645] Gross national expenditure (constant LCU)
# [27/171] done: [646] Gross national expenditure (% of GDP)
# [28/171] done: [648] Exports of goods and services (current LCU)
# [29/171] done: [652] Exports of goods and services (% of GDP)
# [30/171] done: [649] Exports of goods and services (constant 2015 US$)
# [31/171] done: [647] Exports of goods and services (current US$)
# [32/171] done: [650] Exports of goods and services (annual % growth)
# [33/171] done: [651] Exports of goods and services (constant LCU)
# [34/171] done: [653] Gross fixed capital formation, private sector (current LCU)
# [35/171] done: [654] Gross fixed capital formation, private sector (% of GDP)
# [36/171] done: [655] Gross fixed capital formation (current US$)
# [37/171] done: [656] Gross fixed capital formation (current LCU)
# [38/171] done: [657] Gross fixed capital formation (constant 2015 US$)
# [39/171] done: [660] Gross fixed capital formation (% of GDP)
# [40/171] done: [659] Gross fixed capital formation (constant LCU)
# [41/171] done: [662] Changes in inventories (current LCU)
# [42/171] done: [658] Gross fixed capital formation (annual % growth)
# [43/171] done: [661] Changes in inventories (current US$)
# [44/171] done: [663] Changes in inventories (constant LCU)
# [45/171] done: [664] Gross capital formation (current US$)
# [46/171] done: [668] Gross capital formation (constant LCU)
# [47/171] done: [665] Gross capital formation (current LCU)
# [48/171] done: [666] Gross capital formation (constant 2015 US$)
# [49/171] done: [667] Gross capital formation (annual % growth)
# [50/171] done: [670] Imports of goods and services (current US$)
# [51/171] done: [669] Gross capital formation (% of GDP)
# [52/171] done: [671] Imports of goods and services (current LCU)
# [53/171] done: [673] Imports of goods and services (annual % growth)
# [54/171] done: [672] Imports of goods and services (constant 2015 US$)
# [55/171] done: [680] Trade (% of GDP)
# [56/171] done: [674] Imports of goods and services (constant LCU)
# [57/171] done: [675] Imports of goods and services (% of GDP)
# [58/171] done: [677] External balance on goods and services (current LCU)
# [59/171] done: [678] External balance on goods and services (constant LCU)
# [60/171] done: [679] External balance on goods and services (% of GDP)
# [61/171] done: [676] External balance on goods and services (current US$)
# [62/171] done: [682] Agriculture, forestry, and fishing, value added (current US$)
# [63/171] done: [683] Agriculture, forestry, and fishing, value added (current LCU)
# [64/171] done: [685] Agriculture, forestry, and fishing, value added (annual % growth)
# [65/171] done: [688] Financial Intermediary Services Indirectly Measured (FISIM) (current LCU)
# [66/171] done: [689] Financial Intermediary Services Indirectly Measured (FISIM) (constant LCU)
# [67/171] done: [686] Agriculture, forestry, and fishing, value added (constant LCU)
# [68/171] done: [681] Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)
# [69/171] done: [687] Agriculture, forestry, and fishing, value added (% of GDP)
# [70/171] done: [684] Agriculture, forestry, and fishing, value added (constant 2015 US$)
# [71/171] done: [694] Manufacturing, value added (annual % growth)
# [72/171] done: [700] Industry, including construction, value added (annual % growth)
# [73/171] done: [695] Manufacturing, value added (constant LCU)
# [74/171] done: [691] Manufacturing, value added (current US$)
# [75/171] done: [690] Industry, including construction, value added per worker (constant 2015 US$)
# [76/171] done: [693] Manufacturing, value added (constant 2015 US$)
# [77/171] done: [692] Manufacturing, value added (current LCU)
# [78/171] done: [698] Industry, including construction, value added (current LCU)
# [79/171] done: [699] Industry, including construction, value added (constant 2015 US$)
# [80/171] done: [701] Industry, including construction, value added (constant LCU)
# [81/171] done: [696] Manufacturing, value added (% of GDP)
# [82/171] done: [703] Chemicals (% of value added in manufacturing)
# [83/171] done: [704] Food, beverages and tobacco (% of value added in manufacturing)
# [84/171] done: [697] Industry, including construction, value added (current US$)
# [85/171] done: [702] Industry, including construction, value added (% of GDP)
# [86/171] done: [706] Other manufacturing (% of value added in manufacturing)
# [87/171] done: [709] Services, value added per worker (constant 2015 US$)
# [88/171] done: [710] Services, value added (current US$)
# [89/171] done: [705] Machinery and transport equipment (% of value added in manufacturing)
# [90/171] done: [708] Textiles and clothing (% of value added in manufacturing)
# [91/171] done: [712] Services, value added (constant 2015 US$)
# [92/171] done: [716] Adjusted savings, education expenditure (current US$)
# [93/171] done: [715] Services, value added (% of GDP)
# [94/171] done: [713] Services, value added (annual % growth)
# [95/171] done: [714] Services, value added (constant LCU)
# [96/171] done: [711] Services, value added (current LCU)
# [97/171] done: [717] Adjusted savings, education expenditure (% of GNI)
# [98/171] done: [718] Adjusted savings, carbon dioxide damage (current US$)
# [99/171] done: [722] Adjusted savings, consumption of fixed capital (current US$)
# [100/171] done: [723] Adjusted savings, consumption of fixed capital (% of GNI)
# [101/171] done: [725] Adjusted savings, mineral depletion (% of GNI)
# [102/171] done: [724] Adjusted savings, mineral depletion (current US$)
# [103/171] done: [721] Adjusted savings, net forest depletion (% of GNI)
# [104/171] done: [720] Adjusted savings, net forest depletion (current US$)
# [105/171] done: [719] Adjusted savings, carbon dioxide damage (% of GNI)
# [106/171] done: [727] Adjusted savings, energy depletion (% of GNI)
# [107/171] done: [732] Adjusted savings, net national savings (current US$)
# [108/171] done: [733] Adjusted savings, net national savings (% of GNI)
# [109/171] done: [726] Adjusted savings, energy depletion (current US$)
# [110/171] done: [734] Adjusted net national income (current US$)
# [111/171] done: [728] Adjusted savings, particulate emission damage (current US$)
# [112/171] done: [730] Adjusted savings, natural resources depletion (% of GNI)
# [113/171] done: [729] Adjusted savings, particulate emission damage (% of GNI)
# [114/171] done: [736] Adjusted net national income (annual % growth)
# [115/171] done: [731] Adjusted savings, gross savings (% of GNI)
# [116/171] done: [735] Adjusted net national income (constant 2015 US$)
# [117/171] done: [739] Adjusted net national income per capita (annual % growth)
# [118/171] done: [742] Adjusted net savings, excluding particulate emission damage (current US$)
# [119/171] done: [738] Adjusted net national income per capita (constant 2015 US$)
# [120/171] done: [737] Adjusted net national income per capita (current US$)
# [121/171] done: [743] Adjusted net savings, excluding particulate emission damage (% of GNI)
# [122/171] done: [754] Gross Value Added (GVA) at basic prices (constant 2015 US$)
# [123/171] done: [744] Exports as a capacity to import (constant LCU)
# [124/171] done: [740] Adjusted net savings, including particulate emission damage (current US$)
# [125/171] done: [750] Discrepancy in expenditure estimate of GDP (current LCU)
# [126/171] done: [741] Adjusted net savings, including particulate emission damage (% of GNI)
# [127/171] done: [751] Discrepancy in expenditure estimate of GDP (constant LCU)
# [128/171] done: [752] Gross Value Added (GVA) at basic prices (current US$)
# [129/171] done: [755] Gross Value Added (GVA) at basic prices (constant LCU)
# [130/171] done: [758] GDP (current US$)
# [131/171] done: [760] GDP, linked series (current LCU)
# [132/171] done: [759] GDP (current LCU)
# [133/171] done: [763] GDP (constant LCU)
# [134/171] done: [753] Gross Value Added (GVA) at basic prices (current LCU)
# [135/171] done: [762] GDP (annual % growth)
# [136/171] done: [768] GDP per capita (current LCU)
# [137/171] done: [761] GDP (constant 2015 US$)
# [138/171] done: [776] Gross domestic savings (current US$)
# [139/171] done: [769] GDP per capita (constant 2015 US$)
# [140/171] done: [771] GDP per capita (constant LCU)
# [141/171] done: [767] GDP per capita (current US$)
# [142/171] done: [770] GDP per capita (annual % growth)
# [143/171] done: [778] Gross domestic savings (% of GDP)
# [144/171] done: [783] GNI, linked series (current LCU)
# [145/171] done: [777] Gross domestic savings (current LCU)
# [146/171] done: [779] Gross domestic income (constant LCU)
# [147/171] done: [781] GNI (current US$)
# [148/171] done: [780] GNI, Atlas method (current US$)
# [149/171] done: [782] GNI (current LCU)
# [150/171] done: [785] GNI (annual % growth)
# [151/171] done: [784] GNI (constant 2015 US$)
# [152/171] done: [790] GNI per capita (current LCU)
# [153/171] done: [786] GNI (constant LCU)
# [154/171] done: [789] GNI per capita, Atlas method (current US$)
# [155/171] done: [791] GNI per capita (constant 2015 US$)
# [156/171] done: [800] Net primary income (net income from abroad) (current US$)
# [157/171] done: [801] Net primary income (net income from abroad) (current LCU)
# [158/171] done: [792] GNI per capita (annual % growth)
# [159/171] done: [798] Gross savings (% of GNI)
# [160/171] done: [799] Gross savings (% of GDP)
# [161/171] done: [796] Gross savings (current US$)
# [162/171] done: [797] Gross savings (current LCU)
# [163/171] done: [802] Net primary income (net income from abroad) (constant LCU)
# [164/171] done: [793] GNI per capita (constant LCU)
# [165/171] done: [805] Taxes less subsidies on products (constant LCU)
# [166/171] done: [806] Net secondary income (net current transfers from abroad) (current US$)
# [167/171] done: [807] Net secondary income (net current transfers from abroad) (current LCU)
# [168/171] done: [803] Taxes less subsidies on products (current US$)
# [169/171] done: [808] Net secondary income (net current transfers from abroad) (constant LCU)
# [170/171] done: [804] Taxes less subsidies on products (current LCU)
# [171/171] done: [809] Terms of trade adjustment (constant LCU)
